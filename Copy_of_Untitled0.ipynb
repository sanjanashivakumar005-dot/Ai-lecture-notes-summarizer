# %%
# !pip -q install google-genai

# %%
from google import genai
from getpass import getpass

api_key = getpass("Enter your Gemini API Key: ")

client = genai.Client(api_key=api_key)
# Out:
# Enter your Gemini API Key: ··········

# %%
print("AI LECTURE NOTES SUMMARIZER")
print("-"*40)

lecture_text = input("Paste the lecture notes: ")

summary_length = input("Enter summary length (Short / Medium / Detailed): ")
# Out:
# AI LECTURE NOTES SUMMARIZER
# ----------------------------------------
# Paste the lecture notes: Neural networks are computational models inspired by the human brain.  They consist of layers such as input layer, hidden layer and output layer.  Neural networks learn using algorithms like backpropagation and gradient descent. They are widely used in pattern recognition, image classification and speech recognition.
# Enter summary length (Short / Medium / Detailed): Medium

# %%
prompt = f"""
You are an academic assistant.

Summarize the following lecture notes clearly.

Lecture Notes:
{lecture_text}

Summary Length:
{summary_length}

Instructions:
1. Keep the summary clear and simple
2. Use bullet points if needed
3. Focus on important concepts
4. Avoid unnecessary details
"""

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

print("\nSUMMARY")
print("-"*40)
print(response.text)
# Out:
# SUMMARY
# ----------------------------------------
# Here is a clear summary of the lecture notes on neural networks:
#
# Neural networks are computational models that draw inspiration from the human brain. They are characterized by:
#
# *   **Structure:** Organized into distinct layers, including an input layer, one or more hidden layers, and an output layer.
# *   **Learning:** Employ algorithms such as backpropagation and gradient descent to learn from data.
# *   **Applications:** Widely utilized across various fields, notably for tasks like pattern recognition, image classification, and speech recognition.
